# %% [markdown]
# # ecRad numerical gprof
#
# *Last edited: 2024-06-27*
#
# References:
#
# - <https://github.com/ecmwf-ifs/ecrad>
# - <https://github.com/ecmwf-ifs/fiat>
# - <https://confluence.ecmwf.int/display/ECRAD>
# - <https://confluence.ecmwf.int/display/ECRAD/ecRad+practical>
# - <https://github.com/ecmwf-ifs/ecrad/blob/master/practical/ecrad_practical.pdf>

# %% [markdown]
# Build:
#
# ```bash
# $ cd ecrad
# $ make OPTFLAGS=-Og DEBUGFLAGS="-g -pg"
# ```

# %%
# %cd ecrad/bin
# Out:
# /home/x/jlab/ukk23/ecrad/bin

# %%
! ./ecrad --help
# Out:
# STOP Usage: ecrad config.nam input_file.nc output_file.nc

# %%
# %cd ../practical
# Out:
# /home/x/jlab/ukk23/ecrad/practical

# %%
! ./ecrad --help
# Out:
# STOP Usage: ecrad config.nam input_file.nc output_file.nc

# %% [markdown]
# ## Run ecrad (gprof)

# %%
! ./ecrad config.nam era5slice.nc control.nc
# Out:
# -------------------------- OFFLINE ECRAD RADIATION SCHEME --------------------------
# Copyright (C) 2014- ECMWF
# Contact: Robin Hogan (r.j.hogan@ecmwf.int)
# Floating-point precision: double
# General settings:
#   Data files expected in "data"
#   Clear-sky calculations are ON                              (do_clear=T)
#   Saving intermediate radiative properties OFF               (do_save_radiative_properties=F)
#   Saving spectral flux profiles OFF                          (do_save_spectral_flux=F)
#   Shortwave gas model is "RRTMG-IFS"                         (i_gas_model_sw=1)
#   Longwave gas model is "RRTMG-IFS"                          (i_gas_model_lw=1)
#   Aerosols are ON                                            (use_aerosols=T)
#   General aerosol optics OFF                                 (use_general_aerosol_optics=F)
#   Clouds are ON
#   Do cloud/aerosol/surface SW properties per g-point ON      (do_cloud_aerosol_per_sw_g_point=T)
#   Do cloud/aerosol/surface LW properties per g-point ON      (do_cloud_aerosol_per_lw_g_point=T)
#   Represent solar cycle in spectral irradiance OFF           (use_spectral_solar_cycle=F)
#   Scale spectral solar irradiance OFF                        (use_spectral_solar_scaling=F)
# Surface and top-of-atmosphere settings:
#   Saving top-of-atmosphere spectral fluxes OFF               (do_toa_spectral_flux=F)
#   Saving surface shortwave spectral fluxes OFF               (do_surface_sw_spectral_flux=F)
#   Saving surface shortwave fluxes in abledo bands OFF        (do_canopy_fluxes_sw=F)
#   Saving surface longwave fluxes in emissivity bands OFF     (do_canopy_fluxes_lw=F)
#   Longwave derivative calculation is OFF                     (do_lw_derivatives=F)
#   Nearest-neighbour spectral albedo mapping OFF              (do_nearest_spectral_sw_albedo=F)
#   Nearest-neighbour spectral emissivity mapping OFF          (do_nearest_spectral_lw_emiss=F)
#   Planck-weighted surface albedo/emiss mapping ON            (do_weighted_surface_mapping=T)
# Cloud settings:
#   Cloud fraction threshold = .100E-05                        (cloud_fraction_threshold)
#   Cloud mixing-ratio threshold = .100E-08                    (cloud_mixing_ratio_threshold)
#   General cloud optics OFF                                   (use_general_cloud_optics=F)
#   Liquid optics scheme is "SOCRATES"                         (i_liq_model=1)
#   Ice optics scheme is "Fu-IFS"                              (i_ice_model=1)
#   Longwave ice optics bug in Fu scheme is OFF                (do_fu_lw_ice_optics_bug=F)
#   Cloud overlap scheme is "Exp-Ran"                          (i_overlap_scheme=1)
#   Use "beta" overlap parameter is OFF                        (use_beta_overlap=F)
#   Cloud PDF shape is "Gamma"                                 (i_cloud_pdf_shape=1)
#   Cloud inhom decorrelation scaling = .500                   (cloud_inhom_decorr_scaling)
# Solver settings:
#   Shortwave solver is "Tripleclouds"                         (i_solver_sw=4)
#   Shortwave delta scaling after merge with gases OFF         (do_sw_delta_scaling_with_gases=F)
#   Longwave solver is "Tripleclouds"                          (i_solver_lw=4)
#   Longwave cloud scattering is ON                            (do_lw_cloud_scattering=T)
#   Longwave aerosol scattering is OFF                         (do_lw_aerosol_scattering=F)
# Reading RRTMG longwave data file data/RADRRTM
# Reading RRTMG shortwave data file data/RADSRTM
# Aerosol mapping:
#    1 -> hydrophilic type 1: Sea salt, bin 1, 0.03-0.5 micron, OPAC
#    2 -> hydrophilic type 2: Sea salt, bin 2, 0.50-5.0 micron, OPAC
#    3 -> hydrophilic type 3: Sea salt, bin 3, 5.0-20.0 micron, OPAC
#    4 -> hydrophobic type 1: Desert dust, bin 1, 0.03-0.55 micron, (SW) Dubovik et al. 2002 (LW) Fouquart et al. 1987
#    5 -> hydrophobic type 2: Desert dust, bin 2, 0.55-0.90 micron, (SW) Dubovik et al. 2002 (LW) Fouquart et al. 1987
#    6 -> hydrophobic type 3: Desert dust, bin 3, 0.90-20.0 micron, (SW) Dubovik et al. 2002 (LW) Fouquart et al. 1987
#    7 -> hydrophilic type 4: Hydrophilic organic matter, OPAC
#    8 -> hydrophobic type 10: Hydrophobic organic matter, OPAC (hydrophilic at RH=20%)
#    9 -> hydrophobic type 11: Black carbon, OPAC
#   10 -> hydrophobic type 11: Black carbon, OPAC
#   11 -> hydrophilic type 5: Ammonium sulfate (for sulfate), GACP Lacis et al https://gacp.giss.nasa.gov/data_sets/
# Reading NetCDF file era5slice.nc
#   Overriding solar irradiance with     1361.0
#   Scaling overlap decorrelation length by a factor of   1.00
#   Overriding cloud fractional standard deviation with   1.00
#   Warning: variable co_vmr not found
#   Warning: variable hcfc22_vmr not found
#   Warning: variable ccl4_vmr not found
#   Warning: variable no2_vmr not found
# Performing radiative transfer calculations
# Time elapsed in radiative transfer:  0.73932     seconds
# Writing NetCDF file control.nc
# ------------------------------------------------------------------------------------

# %%
# %%bash
# source ${HOME}/conda/bin/activate tf2
# ./plot_output.py era5slice.nc control.nc
# Out:
# WARNING: overwriting environment variables set in the machine
# overwriting variable ['XLA_FLAGS', 'LD_LIBRARY_PATH']
# Plotting output to ./era5slice_control.png

# %%
from PIL import Image
from IPython.display import display

# %%
# %pwd
# Out:
# '/home/x/jlab/ukk23/ecrad/practical'

# %%
display(Image.open('era5slice_control.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1792x1070>

# %% [markdown]
# To plot profiles of the outputs at a latitude of 10◦N :

# %%
# %%bash
# source ${HOME}/conda/bin/activate tf2
# ./plot_output_profile.py 10 era5slice.nc control.nc
# Out:
# WARNING: overwriting environment variables set in the machine
# overwriting variable ['LD_LIBRARY_PATH', 'XLA_FLAGS']
# Plotting output profiles to ./era5slice_control_profile_10N.png

# %%
display(Image.open('era5slice_control_profile_10N.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1534x1056>

# %% [markdown]
# Plots the surface and top-of-atmosphere fluxes for all latitudes:

# %%
# %%bash
# source ${HOME}/conda/bin/activate tf2
# ./plot_output_scalar.py era5slice.nc control.nc
# Out:
# WARNING: overwriting environment variables set in the machine
# overwriting variable ['XLA_FLAGS', 'LD_LIBRARY_PATH']
# Plotting integrated and TOA outputs to .//era5slice_control_surface_and_TOA.png

# %%
display(Image.open('era5slice_control_surface_and_TOA.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1785x1050>

# %%
# %%bash
# source ${HOME}/conda/bin/activate tf2
# ./plot_input_profile.py 10 era5slice.nc
# Out:
# WARNING: overwriting environment variables set in the machine
# overwriting variable ['LD_LIBRARY_PATH', 'XLA_FLAGS']
# Plotting inputs profile to ./era5slice_profile_10N.png

# %%
display(Image.open('era5slice_profile_10N.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1462x1088>

# %% [markdown]
# ## GPROF

# %%
! gprof ./ecrad > ../../report-gprof-ecrad-2024-07-26.txt

# %%
! cat ../../report-gprof-ecrad-2024-07-26.txt
# Out:
# Flat profile:
#
# Each sample counts as 0.01 seconds.
#   %   cumulative   self              self     total
#  time   seconds   seconds    calls  ms/call  ms/call  name
#  17.42      0.27     0.27       12    22.50    34.06  __radiation_tripleclouds_sw_MOD_solver_tripleclouds_sw
#  12.90      0.47     0.20       12    16.67    49.17  __radiation_ifs_rrtm_MOD_gas_optics
#  12.90      0.67     0.20       12    16.67    30.10  __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw
#   9.68      0.82     0.15       11    13.64    13.64  __radiation_aerosol_optics_MOD_add_aerosol_optics
#   7.74      0.94     0.12     4817     0.02     0.02  __radiation_two_stream_MOD_calc_ref_trans_sw
#   4.52      1.01     0.07       12     5.83     5.83  __radiation_ifs_rrtm_MOD_planck_function_atmos
#   3.87      1.07     0.06      358     0.17     0.17  __radiation_two_stream_MOD_calc_no_scattering_transmittance_lw
#   2.58      1.11     0.04    21355     0.00     0.00  __radiation_matrix_MOD_singlemat_x_vec
#   2.58      1.15     0.04    10404     0.00     0.00  __radiation_two_stream_MOD_calc_ref_trans_lw
#   2.58      1.19     0.04      357     0.11     0.11  __radiation_adding_ica_lw_MOD_calc_fluxes_no_scattering_lw
#   2.58      1.23     0.04       12     3.33     3.33  rrtm_taumol4_
#   1.94      1.26     0.03       10     3.00     3.00  srtm_taumol27_
#   1.29      1.28     0.02       12     1.67     1.67  __radiation_cloud_optics_MOD_cloud_optics
#   1.29      1.30     0.02       12     1.67    15.83  rrtm_gas_optical_depth_
#   1.29      1.32     0.02       12     1.67     1.67  rrtm_taumol1_
#   1.29      1.34     0.02       12     1.67     1.67  rrtm_taumol3_
#   1.29      1.36     0.02       12     1.67     1.67  rrtm_taumol5_
#   1.29      1.38     0.02       12     1.67     1.67  rrtm_taumol8_
#   1.29      1.40     0.02       12     1.67     9.17  srtm_gas_optical_depth_
#   1.29      1.42     0.02       11     1.82     1.82  rrtm_taumol9_
#   1.29      1.44     0.02       10     2.00     2.00  srtm_taumol21_
#   0.65      1.45     0.01       12     0.83     0.83  rrtm_setcoef_140gp_
#   0.65      1.46     0.01       12     0.83     0.83  rrtm_taumol11_
#   0.65      1.47     0.01       12     0.83     0.83  rrtm_taumol12_
#   0.65      1.48     0.01       12     0.83     0.83  rrtm_taumol7_
#   0.65      1.49     0.01       12     0.83     0.83  srtm_setcoef_
#   0.65      1.50     0.01       10     1.00     1.00  srtm_taumol17_
#   0.65      1.51     0.01       10     1.00     1.00  srtm_taumol18_
#   0.65      1.52     0.01       10     1.00     1.00  srtm_taumol23_
#   0.65      1.53     0.01        9     1.11     1.11  srtm_taumol29_
#   0.65      1.54     0.01        7     1.43     1.43  __radiation_gas_MOD_put_gas
#   0.65      1.55     0.01                             _init
#   0.00      1.55     0.00   192464     0.00     0.00  __radiation_cloud_optics_MOD_delta_eddington_scat_od
#   0.00      1.55     0.00    98225     0.00     0.00  __radiation_overlap_MOD_calc_alpha_overlap_matrix
#   0.00      1.55     0.00    48331     0.00     0.00  __radiation_aerosol_optics_data_MOD_calc_rh_index
#   0.00      1.55     0.00    10472     0.00     0.00  __radiation_liquid_optics_socrates_MOD_calc_liq_optics_socrates
#   0.00      1.55     0.00     3977     0.00     0.00  __radiation_ice_optics_fu_MOD_calc_ice_optics_fu_sw
#   0.00      1.55     0.00     3970     0.00     0.00  __radiation_ice_optics_fu_MOD_calc_ice_optics_fu_lw
#   0.00      1.55     0.00      357     0.00     0.00  __radiation_aerosol_optics_MOD_delta_eddington_extensive_vec
#   0.00      1.55     0.00      150     0.00     0.00  __radiation_spectral_definition_MOD_calc_planck_function_wavenumber
#   0.00      1.55     0.00       72     0.00     0.00  __easy_netcdf_MOD_get_array_dimensions
#   0.00      1.55     0.00       64     0.00     0.00  __easy_netcdf_MOD_get_variable_id
#   0.00      1.55     0.00       31     0.00     0.00  __easy_netcdf_MOD_get_real_matrix
#   0.00      1.55     0.00       24     0.00     0.00  __radiation_overlap_MOD_calc_overlap_matrices
#   0.00      1.55     0.00       24     0.00     0.00  __radiation_regions_MOD_calc_region_properties
#   0.00      1.55     0.00       23     0.00     0.00  __radiation_config_MOD_print_logical
#   0.00      1.55     0.00       19     0.00     0.00  __radiation_check_MOD_out_of_bounds_2d
#   0.00      1.55     0.00       14     0.00     0.00  __easy_netcdf_MOD_exists
#   0.00      1.55     0.00       13     0.00     0.00  __easy_netcdf_MOD_define_variable
#   0.00      1.55     0.00       13     0.00     0.00  __easy_netcdf_MOD_end_define_mode
#   0.00      1.55     0.00       12     0.00     0.00  __easy_netcdf_MOD_get_rank
#   0.00      1.55     0.00       12     0.00     0.00  __radiation_flux_MOD_calc_surface_spectral
#   0.00      1.55     0.00       12     0.00     0.00  __radiation_flux_MOD_calc_toa_spectral
#   0.00      1.55     0.00       12     0.00     0.00  __radiation_gas_MOD_assert_units_gas
#   0.00      1.55     0.00       12     0.00     0.00  __radiation_gas_MOD_get_gas
#   0.00      1.55     0.00       12     0.00     0.00  __radiation_gas_MOD_scale_gas
#   0.00      1.55     0.00       12     0.00     0.00  __radiation_ifs_rrtm_MOD_planck_function_surf
#   0.00      1.55     0.00       12     0.00   127.50  __radiation_interface_MOD_radiation
#   0.00      1.55     0.00       12     0.00     0.00  __radiation_single_level_MOD_get_albedos
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_prepare_gases_
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_taumol10_
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_taumol13_
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_taumol14_
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_taumol15_
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_taumol16_
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_taumol2_
#   0.00      1.55     0.00       12     0.00     0.00  rrtm_taumol6_
#   0.00      1.55     0.00       11     0.00     0.00  __easy_netcdf_MOD_get_real_array3
#   0.00      1.55     0.00       11     0.00     0.00  __easy_netcdf_MOD_put_real_matrix
#   0.00      1.55     0.00       11     0.00     0.00  __radiation_aerosol_optics_data_MOD_get_line
#   0.00      1.55     0.00       11     0.00     0.00  __radiation_cloud_MOD_crop_cloud_fraction
#   0.00      1.55     0.00       10     0.00     0.00  __radiation_check_MOD_out_of_bounds_3d
#   0.00      1.55     0.00       10     0.00     0.00  __radiation_config_MOD_get_enum_code
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol16_
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol19_
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol20_
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol22_
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol24_
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol25_
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol26_
#   0.00      1.55     0.00       10     0.00     0.00  srtm_taumol28_
#   0.00      1.55     0.00        8     0.00     0.00  __easy_netcdf_MOD_get_real_vector
#   0.00      1.55     0.00        8     0.00     0.00  __radiation_config_MOD_print_enum
#   0.00      1.55     0.00        6     0.00     0.00  __radiation_aerosol_optics_data_MOD_set_hydrophobic_type
#   0.00      1.55     0.00        5     0.00     0.00  __easy_netcdf_MOD_close_netcdf_file
#   0.00      1.55     0.00        5     0.00     0.00  __radiation_aerosol_optics_data_MOD_set_hydrophilic_type
#   0.00      1.55     0.00        4     0.00     0.00  __easy_netcdf_MOD_open_netcdf_file
#   0.00      1.55     0.00        4     0.00     0.00  __easy_netcdf_MOD_transpose_matrices
#   0.00      1.55     0.00        3     0.00     0.00  __radiation_config_MOD_print_real
#   0.00      1.55     0.00        2     0.00     0.00  __easy_netcdf_MOD_define_dimension
#   0.00      1.55     0.00        2     0.00     0.00  __easy_netcdf_MOD_get_global_attribute
#   0.00      1.55     0.00        2     0.00     0.00  __easy_netcdf_MOD_put_real_vector
#   0.00      1.55     0.00        2     0.00     0.00  __radiation_check_MOD_out_of_bounds_1d
#   0.00      1.55     0.00        2     0.00     0.00  __radiation_spectral_definition_MOD_allocate_bands_only
#   0.00      1.55     0.00        2     0.00     0.00  __radiation_spectral_definition_MOD_calc_mapping_from_bands
#   0.00      1.55     0.00        2     0.00     0.00  __radiation_spectral_definition_MOD_deallocate
#   0.00      1.55     0.00        1     0.00    10.00  MAIN__
#   0.00      1.55     0.00        1     0.00     0.00  __easy_netcdf_MOD_create_netcdf_file
#   0.00      1.55     0.00        1     0.00     0.00  __easy_netcdf_MOD_double_precision
#   0.00      1.55     0.00        1     0.00     0.00  __easy_netcdf_MOD_get_real_scalar
#   0.00      1.55     0.00        1     0.00     0.00  __easy_netcdf_MOD_permute_3d_arrays
#   0.00      1.55     0.00        1     0.00     0.00  __easy_netcdf_MOD_put_global_attribute
#   0.00      1.55     0.00        1     0.00     0.00  __easy_netcdf_MOD_put_global_attributes
#   0.00      1.55     0.00        1     0.00     0.00  __ecrad_driver_config_MOD_read_config_from_namelist
#   0.00      1.55     0.00        1     0.00    10.00  __ecrad_driver_read_input_MOD_read_input
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_aerosol_MOD_out_of_physical_bounds
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_aerosol_optics_MOD_setup_aerosol_optics
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_aerosol_optics_data_MOD_initialize_types
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_aerosol_optics_data_MOD_print_description
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_aerosol_optics_data_MOD_set_types
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_aerosol_optics_data_MOD_setup_aerosol_optics
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_cloud_MOD_create_fractional_std
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_cloud_MOD_out_of_physical_bounds
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_cloud_optics_MOD_setup_cloud_optics
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_cloud_optics_data_MOD_setup_cloud_optics
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_config_MOD_consolidate_config
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_config_MOD_consolidate_lw_emiss_intervals
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_config_MOD_consolidate_sw_albedo_intervals
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_config_MOD_print_config
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_config_MOD_read_config_from_namelist
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_flux_MOD_allocate_flux_type
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_flux_MOD_out_of_physical_bounds
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_gas_MOD_allocate_gas
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_gas_MOD_deallocate_gas
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_gas_MOD_out_of_physical_bounds
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_gas_MOD_put_well_mixed_gas
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_gas_MOD_set_units_gas
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_ifs_rrtm_MOD_set_gas_units
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_ifs_rrtm_MOD_setup_gas_optics
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_interface_MOD_set_gas_units
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_interface_MOD_setup_radiation
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_save_MOD_save_fluxes
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_single_level_MOD_init_seed_simple
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_single_level_MOD_out_of_physical_bounds
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_thermodynamics_MOD_calc_saturation_wrt_liquid
#   0.00      1.55     0.00        1     0.00     0.00  __radiation_thermodynamics_MOD_out_of_physical_bounds
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb10_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb11_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb12_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb13_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb14_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb15_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb16_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb1_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb2_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb3_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb4_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb5_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb6_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb7_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb8_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_cmbgb9_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_init_140gp_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb10_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb11_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb12_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb13_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb14_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb15_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb16_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb1_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb2_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb3_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb4_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb5_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb6_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb7_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb8_
#   0.00      1.55     0.00        1     0.00     0.00  rrtm_kgb9_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb16_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb17_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb18_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb19_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb20_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb21_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb22_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb23_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb24_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb25_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb26_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb27_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb28_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_cmbgb29_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_init_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb16_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb17_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb18_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb19_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb20_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb21_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb22_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb23_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb24_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb25_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb26_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb27_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb28_
#   0.00      1.55     0.00        1     0.00     0.00  srtm_kgb29_
#   0.00      1.55     0.00        1     0.00     0.00  surrtab_
#   0.00      1.55     0.00        1     0.00     0.00  surrtftr_
#   0.00      1.55     0.00        1     0.00     0.00  surrtpk_
#   0.00      1.55     0.00        1     0.00     0.00  surrtrf_
#   0.00      1.55     0.00        1     0.00     0.00  susrtm_
#
#  %         the percentage of the total running time of the
# time       program used by this function.
#
# cumulative a running sum of the number of seconds accounted
#  seconds   for by this function and those listed above it.
#
#  self      the number of seconds accounted for by this
# seconds    function alone.  This is the major sort for this
#            listing.
#
# calls      the number of times this function was invoked, if
#            this function is profiled, else blank.
#
#  self      the average number of milliseconds spent in this
# ms/call    function per call, if this function is profiled,
# 	   else blank.
#
#  total     the average number of milliseconds spent in this
# ms/call    function and its descendents per call, if this
# 	   function is profiled, else blank.
#
# name       the name of the function.  This is the minor sort
#            for this listing. The index shows the location of
# 	   the function in the gprof listing. If the index is
# 	   in parenthesis it shows where it would appear in
# 	   the gprof listing if it were to be printed.
#
# Copyright (C) 2012-2022 Free Software Foundation, Inc.
#
# Copying and distribution of this file, with or without modification,
# are permitted in any medium without royalty provided the copyright
# notice and this notice are preserved.
#
# 		     Call graph (explanation follows)
#
#
# granularity: each sample hit covers 4 byte(s) for 0.65% of 1.55 seconds
#
# index % time    self  children    called     name
#                                                  <spontaneous>
# [1]     98.7    0.00    1.53                 frame_dummy [1]
#                 0.00    1.53      12/12          __radiation_interface_MOD_radiation [2]
# -----------------------------------------------
#                 0.00    1.53      12/12          frame_dummy [1]
# [2]     98.7    0.00    1.53      12         __radiation_interface_MOD_radiation [2]
#                 0.20    0.39      12/12          __radiation_ifs_rrtm_MOD_gas_optics [3]
#                 0.27    0.14      12/12          __radiation_tripleclouds_sw_MOD_solver_tripleclouds_sw [4]
#                 0.20    0.16      12/12          __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw [5]
#                 0.15    0.00      11/11          __radiation_aerosol_optics_MOD_add_aerosol_optics [7]
#                 0.02    0.00      12/12          __radiation_cloud_optics_MOD_cloud_optics [23]
#                 0.00    0.00      12/12          __radiation_single_level_MOD_get_albedos [153]
#                 0.00    0.00      12/12          __radiation_flux_MOD_calc_surface_spectral [147]
#                 0.00    0.00      12/12          __radiation_flux_MOD_calc_toa_spectral [148]
#                 0.00    0.00      11/11          __radiation_cloud_MOD_crop_cloud_fraction [157]
# -----------------------------------------------
#                 0.20    0.39      12/12          __radiation_interface_MOD_radiation [2]
# [3]     38.1    0.20    0.39      12         __radiation_ifs_rrtm_MOD_gas_optics [3]
#                 0.02    0.17      12/12          rrtm_gas_optical_depth_ [6]
#                 0.02    0.09      12/12          srtm_gas_optical_depth_ [9]
#                 0.07    0.00      12/12          __radiation_ifs_rrtm_MOD_planck_function_atmos [10]
#                 0.01    0.00      12/12          rrtm_setcoef_140gp_ [24]
#                 0.01    0.00      12/12          srtm_setcoef_ [28]
#                 0.00    0.00      12/12          __radiation_gas_MOD_assert_units_gas [149]
#                 0.00    0.00      12/12          rrtm_prepare_gases_ [38]
#                 0.00    0.00      12/12          __radiation_ifs_rrtm_MOD_planck_function_surf [152]
# -----------------------------------------------
#                 0.27    0.14      12/12          __radiation_interface_MOD_radiation [2]
# [4]     26.4    0.27    0.14      12         __radiation_tripleclouds_sw_MOD_solver_tripleclouds_sw [4]
#                 0.12    0.00    4817/4817        __radiation_two_stream_MOD_calc_ref_trans_sw [8]
#                 0.02    0.00   10021/21355       __radiation_matrix_MOD_singlemat_x_vec [13]
#                 0.00    0.00      12/24          __radiation_regions_MOD_calc_region_properties [140]
#                 0.00    0.00      12/24          __radiation_overlap_MOD_calc_overlap_matrices [139]
# -----------------------------------------------
#                 0.20    0.16      12/12          __radiation_interface_MOD_radiation [2]
# [5]     23.3    0.20    0.16      12         __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw [5]
#                 0.06    0.00     358/358         __radiation_two_stream_MOD_calc_no_scattering_transmittance_lw [11]
#                 0.04    0.00   10404/10404       __radiation_two_stream_MOD_calc_ref_trans_lw [14]
#                 0.04    0.00     357/357         __radiation_adding_ica_lw_MOD_calc_fluxes_no_scattering_lw [15]
#                 0.02    0.00   11334/21355       __radiation_matrix_MOD_singlemat_x_vec [13]
#                 0.00    0.00      12/24          __radiation_regions_MOD_calc_region_properties [140]
#                 0.00    0.00      12/24          __radiation_overlap_MOD_calc_overlap_matrices [139]
# -----------------------------------------------
#                 0.02    0.17      12/12          __radiation_ifs_rrtm_MOD_gas_optics [3]
# [6]     12.3    0.02    0.17      12         rrtm_gas_optical_depth_ [6]
#                 0.04    0.00      12/12          rrtm_taumol4_ [12]
#                 0.02    0.00      12/12          rrtm_taumol1_ [17]
#                 0.02    0.00      12/12          rrtm_taumol3_ [18]
#                 0.02    0.00      12/12          rrtm_taumol5_ [19]
#                 0.02    0.00      12/12          rrtm_taumol8_ [20]
#                 0.02    0.00      11/11          rrtm_taumol9_ [21]
#                 0.01    0.00      12/12          rrtm_taumol7_ [27]
#                 0.01    0.00      12/12          rrtm_taumol11_ [25]
#                 0.01    0.00      12/12          rrtm_taumol12_ [26]
#                 0.00    0.00      12/12          rrtm_taumol2_ [44]
#                 0.00    0.00      12/12          rrtm_taumol6_ [45]
#                 0.00    0.00      12/12          rrtm_taumol10_ [39]
#                 0.00    0.00      12/12          rrtm_taumol13_ [40]
#                 0.00    0.00      12/12          rrtm_taumol14_ [41]
#                 0.00    0.00      12/12          rrtm_taumol15_ [42]
#                 0.00    0.00      12/12          rrtm_taumol16_ [43]
# -----------------------------------------------
#                 0.15    0.00      11/11          __radiation_interface_MOD_radiation [2]
# [7]      9.7    0.15    0.00      11         __radiation_aerosol_optics_MOD_add_aerosol_optics [7]
#                 0.00    0.00   48331/48331       __radiation_aerosol_optics_data_MOD_calc_rh_index [130]
#                 0.00    0.00     357/357         __radiation_aerosol_optics_MOD_delta_eddington_extensive_vec [134]
#                 0.00    0.00      12/12          __radiation_gas_MOD_get_gas [150]
# -----------------------------------------------
#                 0.12    0.00    4817/4817        __radiation_tripleclouds_sw_MOD_solver_tripleclouds_sw [4]
# [8]      7.7    0.12    0.00    4817         __radiation_two_stream_MOD_calc_ref_trans_sw [8]
# -----------------------------------------------
#                 0.02    0.09      12/12          __radiation_ifs_rrtm_MOD_gas_optics [3]
# [9]      7.1    0.02    0.09      12         srtm_gas_optical_depth_ [9]
#                 0.03    0.00      10/10          srtm_taumol27_ [16]
#                 0.02    0.00      10/10          srtm_taumol21_ [22]
#                 0.01    0.00      10/10          srtm_taumol17_ [29]
#                 0.01    0.00      10/10          srtm_taumol18_ [30]
#                 0.01    0.00      10/10          srtm_taumol23_ [31]
#                 0.01    0.00       9/9           srtm_taumol29_ [32]
#                 0.00    0.00      10/10          srtm_taumol16_ [46]
#                 0.00    0.00      10/10          srtm_taumol19_ [47]
#                 0.00    0.00      10/10          srtm_taumol20_ [48]
#                 0.00    0.00      10/10          srtm_taumol22_ [49]
#                 0.00    0.00      10/10          srtm_taumol24_ [50]
#                 0.00    0.00      10/10          srtm_taumol25_ [51]
#                 0.00    0.00      10/10          srtm_taumol26_ [52]
#                 0.00    0.00      10/10          srtm_taumol28_ [53]
# -----------------------------------------------
#                 0.07    0.00      12/12          __radiation_ifs_rrtm_MOD_gas_optics [3]
# [10]     4.5    0.07    0.00      12         __radiation_ifs_rrtm_MOD_planck_function_atmos [10]
# -----------------------------------------------
#                 0.06    0.00     358/358         __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw [5]
# [11]     3.9    0.06    0.00     358         __radiation_two_stream_MOD_calc_no_scattering_transmittance_lw [11]
# -----------------------------------------------
#                 0.04    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [12]     2.6    0.04    0.00      12         rrtm_taumol4_ [12]
# -----------------------------------------------
#                 0.02    0.00   10021/21355       __radiation_tripleclouds_sw_MOD_solver_tripleclouds_sw [4]
#                 0.02    0.00   11334/21355       __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw [5]
# [13]     2.6    0.04    0.00   21355         __radiation_matrix_MOD_singlemat_x_vec [13]
# -----------------------------------------------
#                 0.04    0.00   10404/10404       __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw [5]
# [14]     2.6    0.04    0.00   10404         __radiation_two_stream_MOD_calc_ref_trans_lw [14]
# -----------------------------------------------
#                 0.04    0.00     357/357         __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw [5]
# [15]     2.6    0.04    0.00     357         __radiation_adding_ica_lw_MOD_calc_fluxes_no_scattering_lw [15]
# -----------------------------------------------
#                 0.03    0.00      10/10          srtm_gas_optical_depth_ [9]
# [16]     1.9    0.03    0.00      10         srtm_taumol27_ [16]
# -----------------------------------------------
#                 0.02    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [17]     1.3    0.02    0.00      12         rrtm_taumol1_ [17]
# -----------------------------------------------
#                 0.02    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [18]     1.3    0.02    0.00      12         rrtm_taumol3_ [18]
# -----------------------------------------------
#                 0.02    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [19]     1.3    0.02    0.00      12         rrtm_taumol5_ [19]
# -----------------------------------------------
#                 0.02    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [20]     1.3    0.02    0.00      12         rrtm_taumol8_ [20]
# -----------------------------------------------
#                 0.02    0.00      11/11          rrtm_gas_optical_depth_ [6]
# [21]     1.3    0.02    0.00      11         rrtm_taumol9_ [21]
# -----------------------------------------------
#                 0.02    0.00      10/10          srtm_gas_optical_depth_ [9]
# [22]     1.3    0.02    0.00      10         srtm_taumol21_ [22]
# -----------------------------------------------
#                 0.02    0.00      12/12          __radiation_interface_MOD_radiation [2]
# [23]     1.3    0.02    0.00      12         __radiation_cloud_optics_MOD_cloud_optics [23]
#                 0.00    0.00  192464/192464      __radiation_cloud_optics_MOD_delta_eddington_scat_od [128]
#                 0.00    0.00   10472/10472       __radiation_liquid_optics_socrates_MOD_calc_liq_optics_socrates [131]
#                 0.00    0.00    3977/3977        __radiation_ice_optics_fu_MOD_calc_ice_optics_fu_sw [132]
#                 0.00    0.00    3970/3970        __radiation_ice_optics_fu_MOD_calc_ice_optics_fu_lw [133]
# -----------------------------------------------
#                 0.01    0.00      12/12          __radiation_ifs_rrtm_MOD_gas_optics [3]
# [24]     0.6    0.01    0.00      12         rrtm_setcoef_140gp_ [24]
# -----------------------------------------------
#                 0.01    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [25]     0.6    0.01    0.00      12         rrtm_taumol11_ [25]
# -----------------------------------------------
#                 0.01    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [26]     0.6    0.01    0.00      12         rrtm_taumol12_ [26]
# -----------------------------------------------
#                 0.01    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [27]     0.6    0.01    0.00      12         rrtm_taumol7_ [27]
# -----------------------------------------------
#                 0.01    0.00      12/12          __radiation_ifs_rrtm_MOD_gas_optics [3]
# [28]     0.6    0.01    0.00      12         srtm_setcoef_ [28]
# -----------------------------------------------
#                 0.01    0.00      10/10          srtm_gas_optical_depth_ [9]
# [29]     0.6    0.01    0.00      10         srtm_taumol17_ [29]
# -----------------------------------------------
#                 0.01    0.00      10/10          srtm_gas_optical_depth_ [9]
# [30]     0.6    0.01    0.00      10         srtm_taumol18_ [30]
# -----------------------------------------------
#                 0.01    0.00      10/10          srtm_gas_optical_depth_ [9]
# [31]     0.6    0.01    0.00      10         srtm_taumol23_ [31]
# -----------------------------------------------
#                 0.01    0.00       9/9           srtm_gas_optical_depth_ [9]
# [32]     0.6    0.01    0.00       9         srtm_taumol29_ [32]
# -----------------------------------------------
#                 0.00    0.01       1/1           main [34]
# [33]     0.6    0.00    0.01       1         MAIN__ [33]
#                 0.00    0.01       1/1           __ecrad_driver_read_input_MOD_read_input [36]
#                 0.00    0.00       1/1           __radiation_config_MOD_read_config_from_namelist [196]
#                 0.00    0.00       1/1           __ecrad_driver_config_MOD_read_config_from_namelist [181]
#                 0.00    0.00       1/1           __radiation_interface_MOD_setup_radiation [207]
#                 0.00    0.00       1/4           __easy_netcdf_MOD_open_netcdf_file [165]
#                 0.00    0.00       1/4           __easy_netcdf_MOD_transpose_matrices [166]
#                 0.00    0.00       1/5           __easy_netcdf_MOD_close_netcdf_file [163]
#                 0.00    0.00       1/1           __radiation_interface_MOD_set_gas_units [206]
#                 0.00    0.00       1/1           __radiation_thermodynamics_MOD_calc_saturation_wrt_liquid [211]
#                 0.00    0.00       1/1           __radiation_gas_MOD_out_of_physical_bounds [201]
#                 0.00    0.00       1/1           __radiation_single_level_MOD_out_of_physical_bounds [210]
#                 0.00    0.00       1/1           __radiation_thermodynamics_MOD_out_of_physical_bounds [212]
#                 0.00    0.00       1/1           __radiation_cloud_MOD_out_of_physical_bounds [189]
#                 0.00    0.00       1/1           __radiation_aerosol_MOD_out_of_physical_bounds [182]
#                 0.00    0.00       1/1           __radiation_flux_MOD_allocate_flux_type [197]
#                 0.00    0.00       1/1           __radiation_config_MOD_print_config [195]
#                 0.00    0.00       1/1           __radiation_flux_MOD_out_of_physical_bounds [198]
#                 0.00    0.00       1/1           __radiation_save_MOD_save_fluxes [208]
# -----------------------------------------------
#                                                  <spontaneous>
# [34]     0.6    0.00    0.01                 main [34]
#                 0.00    0.01       1/1           MAIN__ [33]
# -----------------------------------------------
#                 0.01    0.00       7/7           __ecrad_driver_read_input_MOD_read_input [36]
# [35]     0.6    0.01    0.00       7         __radiation_gas_MOD_put_gas [35]
# -----------------------------------------------
#                 0.00    0.01       1/1           MAIN__ [33]
# [36]     0.6    0.00    0.01       1         __ecrad_driver_read_input_MOD_read_input [36]
#                 0.01    0.00       7/7           __radiation_gas_MOD_put_gas [35]
#                 0.00    0.00      17/31          __easy_netcdf_MOD_get_real_matrix [138]
#                 0.00    0.00      12/12          __easy_netcdf_MOD_get_rank [146]
#                 0.00    0.00      12/12          __radiation_gas_MOD_scale_gas [151]
#                 0.00    0.00      10/14          __easy_netcdf_MOD_exists [143]
#                 0.00    0.00       2/8           __easy_netcdf_MOD_get_real_vector [160]
#                 0.00    0.00       1/1           __radiation_single_level_MOD_init_seed_simple [209]
#                 0.00    0.00       1/1           __radiation_cloud_MOD_create_fractional_std [188]
#                 0.00    0.00       1/11          __easy_netcdf_MOD_get_real_array3 [154]
#                 0.00    0.00       1/1           __radiation_gas_MOD_allocate_gas [199]
#                 0.00    0.00       1/1           __easy_netcdf_MOD_get_real_scalar [177]
#                 0.00    0.00       1/1           __radiation_gas_MOD_put_well_mixed_gas [202]
# -----------------------------------------------
#                                                  <spontaneous>
# [37]     0.6    0.01    0.00                 _init [37]
# -----------------------------------------------
#                 0.00    0.00      12/12          __radiation_ifs_rrtm_MOD_gas_optics [3]
# [38]     0.0    0.00    0.00      12         rrtm_prepare_gases_ [38]
# -----------------------------------------------
#                 0.00    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [39]     0.0    0.00    0.00      12         rrtm_taumol10_ [39]
# -----------------------------------------------
#                 0.00    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [40]     0.0    0.00    0.00      12         rrtm_taumol13_ [40]
# -----------------------------------------------
#                 0.00    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [41]     0.0    0.00    0.00      12         rrtm_taumol14_ [41]
# -----------------------------------------------
#                 0.00    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [42]     0.0    0.00    0.00      12         rrtm_taumol15_ [42]
# -----------------------------------------------
#                 0.00    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [43]     0.0    0.00    0.00      12         rrtm_taumol16_ [43]
# -----------------------------------------------
#                 0.00    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [44]     0.0    0.00    0.00      12         rrtm_taumol2_ [44]
# -----------------------------------------------
#                 0.00    0.00      12/12          rrtm_gas_optical_depth_ [6]
# [45]     0.0    0.00    0.00      12         rrtm_taumol6_ [45]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [46]     0.0    0.00    0.00      10         srtm_taumol16_ [46]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [47]     0.0    0.00    0.00      10         srtm_taumol19_ [47]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [48]     0.0    0.00    0.00      10         srtm_taumol20_ [48]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [49]     0.0    0.00    0.00      10         srtm_taumol22_ [49]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [50]     0.0    0.00    0.00      10         srtm_taumol24_ [50]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [51]     0.0    0.00    0.00      10         srtm_taumol25_ [51]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [52]     0.0    0.00    0.00      10         srtm_taumol26_ [52]
# -----------------------------------------------
#                 0.00    0.00      10/10          srtm_gas_optical_depth_ [9]
# [53]     0.0    0.00    0.00      10         srtm_taumol28_ [53]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [54]     0.0    0.00    0.00       1         rrtm_cmbgb10_ [54]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [55]     0.0    0.00    0.00       1         rrtm_cmbgb11_ [55]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [56]     0.0    0.00    0.00       1         rrtm_cmbgb12_ [56]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [57]     0.0    0.00    0.00       1         rrtm_cmbgb13_ [57]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [58]     0.0    0.00    0.00       1         rrtm_cmbgb14_ [58]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [59]     0.0    0.00    0.00       1         rrtm_cmbgb15_ [59]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [60]     0.0    0.00    0.00       1         rrtm_cmbgb16_ [60]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [61]     0.0    0.00    0.00       1         rrtm_cmbgb1_ [61]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [62]     0.0    0.00    0.00       1         rrtm_cmbgb2_ [62]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [63]     0.0    0.00    0.00       1         rrtm_cmbgb3_ [63]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [64]     0.0    0.00    0.00       1         rrtm_cmbgb4_ [64]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [65]     0.0    0.00    0.00       1         rrtm_cmbgb5_ [65]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [66]     0.0    0.00    0.00       1         rrtm_cmbgb6_ [66]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [67]     0.0    0.00    0.00       1         rrtm_cmbgb7_ [67]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [68]     0.0    0.00    0.00       1         rrtm_cmbgb8_ [68]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [69]     0.0    0.00    0.00       1         rrtm_cmbgb9_ [69]
# -----------------------------------------------
#                 0.00    0.00       1/1           __radiation_ifs_rrtm_MOD_setup_gas_optics [205]
# [70]     0.0    0.00    0.00       1         rrtm_init_140gp_ [70]
#                 0.00    0.00       1/1           surrtftr_ [117]
#                 0.00    0.00       1/1           rrtm_kgb3_ [80]
#                 0.00    0.00       1/1           rrtm_kgb2_ [79]
#                 0.00    0.00       1/1           rrtm_kgb1_ [78]
#                 0.00    0.00       1/1           rrtm_kgb7_ [84]
#                 0.00    0.00       1/1           rrtm_kgb6_ [83]
#                 0.00    0.00       1/1           rrtm_kgb5_ [82]
#                 0.00    0.00       1/1           rrtm_kgb4_ [81]
#                 0.00    0.00       1/1           rrtm_kgb10_ [71]
#                 0.00    0.00       1/1           rrtm_kgb9_ [86]
#                 0.00    0.00       1/1           rrtm_kgb8_ [85]
#                 0.00    0.00       1/1           rrtm_kgb13_ [74]
#                 0.00    0.00       1/1           rrtm_kgb12_ [73]
#                 0.00    0.00       1/1           rrtm_kgb11_ [72]
#                 0.00    0.00       1/1           rrtm_kgb16_ [77]
#                 0.00    0.00       1/1           rrtm_kgb15_ [76]
#                 0.00    0.00       1/1           rrtm_kgb14_ [75]
#                 0.00    0.00       1/1           rrtm_cmbgb3_ [63]
#                 0.00    0.00       1/1           rrtm_cmbgb2_ [62]
#                 0.00    0.00       1/1           rrtm_cmbgb1_ [61]
#                 0.00    0.00       1/1           rrtm_cmbgb6_ [66]
#                 0.00    0.00       1/1           rrtm_cmbgb5_ [65]
#                 0.00    0.00       1/1           rrtm_cmbgb4_ [64]
#                 0.00    0.00       1/1           rrtm_cmbgb10_ [54]
#                 0.00    0.00       1/1           rrtm_cmbgb9_ [69]
#                 0.00    0.00       1/1           rrtm_cmbgb8_ [68]
#                 0.00    0.00       1/1           rrtm_cmbgb7_ [67]
#                 0.00    0.00       1/1           rrtm_cmbgb13_ [57]
#                 0.00    0.00       1/1           rrtm_cmbgb12_ [56]
#                 0.00    0.00       1/1           rrtm_cmbgb11_ [55]
#                 0.00    0.00       1/1           rrtm_cmbgb16_ [60]
#                 0.00    0.00       1/1           rrtm_cmbgb15_ [59]
#                 0.00    0.00       1/1           rrtm_cmbgb14_ [58]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [71]     0.0    0.00    0.00       1         rrtm_kgb10_ [71]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [72]     0.0    0.00    0.00       1         rrtm_kgb11_ [72]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [73]     0.0    0.00    0.00       1         rrtm_kgb12_ [73]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [74]     0.0    0.00    0.00       1         rrtm_kgb13_ [74]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [75]     0.0    0.00    0.00       1         rrtm_kgb14_ [75]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [76]     0.0    0.00    0.00       1         rrtm_kgb15_ [76]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [77]     0.0    0.00    0.00       1         rrtm_kgb16_ [77]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [78]     0.0    0.00    0.00       1         rrtm_kgb1_ [78]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [79]     0.0    0.00    0.00       1         rrtm_kgb2_ [79]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [80]     0.0    0.00    0.00       1         rrtm_kgb3_ [80]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [81]     0.0    0.00    0.00       1         rrtm_kgb4_ [81]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [82]     0.0    0.00    0.00       1         rrtm_kgb5_ [82]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [83]     0.0    0.00    0.00       1         rrtm_kgb6_ [83]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [84]     0.0    0.00    0.00       1         rrtm_kgb7_ [84]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [85]     0.0    0.00    0.00       1         rrtm_kgb8_ [85]
# -----------------------------------------------
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# [86]     0.0    0.00    0.00       1         rrtm_kgb9_ [86]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [87]     0.0    0.00    0.00       1         srtm_cmbgb16_ [87]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [88]     0.0    0.00    0.00       1         srtm_cmbgb17_ [88]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [89]     0.0    0.00    0.00       1         srtm_cmbgb18_ [89]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [90]     0.0    0.00    0.00       1         srtm_cmbgb19_ [90]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [91]     0.0    0.00    0.00       1         srtm_cmbgb20_ [91]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [92]     0.0    0.00    0.00       1         srtm_cmbgb21_ [92]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [93]     0.0    0.00    0.00       1         srtm_cmbgb22_ [93]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [94]     0.0    0.00    0.00       1         srtm_cmbgb23_ [94]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [95]     0.0    0.00    0.00       1         srtm_cmbgb24_ [95]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [96]     0.0    0.00    0.00       1         srtm_cmbgb25_ [96]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [97]     0.0    0.00    0.00       1         srtm_cmbgb26_ [97]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [98]     0.0    0.00    0.00       1         srtm_cmbgb27_ [98]
# -----------------------------------------------
#                 0.00    0.00       1/1           srtm_init_ [101]
# [99]     0.0    0.00    0.00       1         srtm_cmbgb28_ [99]
# -----------------------------------------------
# ...
# [201]    0.0    0.00    0.00       1         __radiation_gas_MOD_out_of_physical_bounds [201]
#                 0.00    0.00       1/10          __radiation_check_MOD_out_of_bounds_3d [158]
# -----------------------------------------------
#                 0.00    0.00       1/1           __ecrad_driver_read_input_MOD_read_input [36]
# [202]    0.0    0.00    0.00       1         __radiation_gas_MOD_put_well_mixed_gas [202]
# -----------------------------------------------
#                                    8             __radiation_gas_MOD_set_units_gas [203]
#                 0.00    0.00       1/1           __radiation_ifs_rrtm_MOD_set_gas_units [204]
# [203]    0.0    0.00    0.00       1+8       __radiation_gas_MOD_set_units_gas [203]
#                                    8             __radiation_gas_MOD_set_units_gas [203]
# -----------------------------------------------
#                 0.00    0.00       1/1           __radiation_interface_MOD_set_gas_units [206]
# [204]    0.0    0.00    0.00       1         __radiation_ifs_rrtm_MOD_set_gas_units [204]
#                 0.00    0.00       1/1           __radiation_gas_MOD_set_units_gas [203]
# -----------------------------------------------
#                 0.00    0.00       1/1           __radiation_interface_MOD_setup_radiation [207]
# [205]    0.0    0.00    0.00       1         __radiation_ifs_rrtm_MOD_setup_gas_optics [205]
#                 0.00    0.00       2/2           __radiation_spectral_definition_MOD_allocate_bands_only [172]
#                 0.00    0.00       1/1           surrtrf_ [119]
#                 0.00    0.00       1/1           surrtpk_ [118]
#                 0.00    0.00       1/1           surrtab_ [116]
#                 0.00    0.00       1/1           srtm_init_ [101]
#                 0.00    0.00       1/1           rrtm_init_140gp_ [70]
# -----------------------------------------------
#                 0.00    0.00       1/1           MAIN__ [33]
# [206]    0.0    0.00    0.00       1         __radiation_interface_MOD_set_gas_units [206]
#                 0.00    0.00       1/1           __radiation_ifs_rrtm_MOD_set_gas_units [204]
# -----------------------------------------------
#                 0.00    0.00       1/1           MAIN__ [33]
# [207]    0.0    0.00    0.00       1         __radiation_interface_MOD_setup_radiation [207]
#                 0.00    0.00       1/1           __radiation_config_MOD_consolidate_config [192]
#                 0.00    0.00       1/1           __radiation_ifs_rrtm_MOD_setup_gas_optics [205]
#                 0.00    0.00       1/1           __radiation_config_MOD_consolidate_sw_albedo_intervals [194]
#                 0.00    0.00       1/1           __radiation_config_MOD_consolidate_lw_emiss_intervals [193]
#                 0.00    0.00       1/1           __radiation_cloud_optics_MOD_setup_cloud_optics [190]
#                 0.00    0.00       1/1           __radiation_aerosol_optics_MOD_setup_aerosol_optics [183]
# -----------------------------------------------
#                 0.00    0.00       1/1           MAIN__ [33]
# [208]    0.0    0.00    0.00       1         __radiation_save_MOD_save_fluxes [208]
#                 0.00    0.00      13/13          __easy_netcdf_MOD_define_variable [144]
#                 0.00    0.00      11/11          __easy_netcdf_MOD_put_real_matrix [155]
#                 0.00    0.00       2/2           __easy_netcdf_MOD_define_dimension [168]
#                 0.00    0.00       2/2           __easy_netcdf_MOD_put_real_vector [170]
#                 0.00    0.00       1/1           __easy_netcdf_MOD_create_netcdf_file [175]
#                 0.00    0.00       1/4           __easy_netcdf_MOD_transpose_matrices [166]
#                 0.00    0.00       1/1           __easy_netcdf_MOD_double_precision [176]
#                 0.00    0.00       1/1           __easy_netcdf_MOD_permute_3d_arrays [178]
#                 0.00    0.00       1/1           __easy_netcdf_MOD_put_global_attributes [180]
#                 0.00    0.00       1/5           __easy_netcdf_MOD_close_netcdf_file [163]
#                 0.00    0.00       1/1           __easy_netcdf_MOD_put_global_attribute [179]
# -----------------------------------------------
#                 0.00    0.00       1/1           __ecrad_driver_read_input_MOD_read_input [36]
# [209]    0.0    0.00    0.00       1         __radiation_single_level_MOD_init_seed_simple [209]
# -----------------------------------------------
#                 0.00    0.00       1/1           MAIN__ [33]
# [210]    0.0    0.00    0.00       1         __radiation_single_level_MOD_out_of_physical_bounds [210]
#                 0.00    0.00       3/19          __radiation_check_MOD_out_of_bounds_2d [142]
#                 0.00    0.00       2/2           __radiation_check_MOD_out_of_bounds_1d [171]
# -----------------------------------------------
#                 0.00    0.00       1/1           MAIN__ [33]
# [211]    0.0    0.00    0.00       1         __radiation_thermodynamics_MOD_calc_saturation_wrt_liquid [211]
# -----------------------------------------------
#                 0.00    0.00       1/1           MAIN__ [33]
# [212]    0.0    0.00    0.00       1         __radiation_thermodynamics_MOD_out_of_physical_bounds [212]
#                 0.00    0.00       3/19          __radiation_check_MOD_out_of_bounds_2d [142]
# -----------------------------------------------
#
#  This table describes the call tree of the program, and was sorted by
#  the total amount of time spent in each function and its children.
#
#  Each entry in this table consists of several lines.  The line with the
#  index number at the left hand margin lists the current function.
#  The lines above it list the functions that called this function,
#  and the lines below it list the functions this one called.
#  This line lists:
#      index	A unique number given to each element of the table.
# 		Index numbers are sorted numerically.
# 		The index number is printed next to every function name so
# 		it is easier to look up where the function is in the table.
#
#      % time	This is the percentage of the `total' time that was spent
# 		in this function and its children.  Note that due to
# 		different viewpoints, functions excluded by options, etc,
# 		these numbers will NOT add up to 100%.
#
#      self	This is the total amount of time spent in this function.
#
#      children	This is the total amount of time propagated into this
# 		function by its children.
#
#      called	This is the number of times the function was called.
# 		If the function called itself recursively, the number
# 		only includes non-recursive calls, and is followed by
# 		a `+' and the number of recursive calls.
#
#      name	The name of the current function.  The index number is
# 		printed after it.  If the function is a member of a
# 		cycle, the cycle number is printed between the
# 		function's name and the index number.
#
#
#  For the function's parents, the fields have the following meanings:
#
#      self	This is the amount of time that was propagated directly
# 		from the function into this parent.
#
#      children	This is the amount of time that was propagated from
# 		the function's children into this parent.
#
#      called	This is the number of times this parent called the
# 		function `/' the total number of times the function
# 		was called.  Recursive calls to the function are not
# 		included in the number after the `/'.
#
#      name	This is the name of the parent.  The parent's index
# 		number is printed after it.  If the parent is a
# 		member of a cycle, the cycle number is printed between
# 		the name and the index number.
#
#  If the parents of the function cannot be determined, the word
#  `<spontaneous>' is printed in the `name' field, and all the other
#  fields are blank.
#
#  For the function's children, the fields have the following meanings:
#
#      self	This is the amount of time that was propagated directly
# 		from the child into the function.
#
#      children	This is the amount of time that was propagated from the
# 		child's children to the function.
#
#      called	This is the number of times the function called
# 		this child `/' the total number of times the child
# 		was called.  Recursive calls by the child are not
# 		listed in the number after the `/'.
#
#      name	This is the name of the child.  The child's index
# 		number is printed after it.  If the child is a
# 		member of a cycle, the cycle number is printed
# 		between the name and the index number.
#
#  If there are any cycles (circles) in the call graph, there is an
#  entry for the cycle-as-a-whole.  This entry shows who called the
#  cycle (as parents) and the members of the cycle (as children.)
#  The `+' recursive calls entry shows the number of function calls that
#  were internal to the cycle, and the calls entry for each member shows,
#  for that member, how many times it was called from other members of
#  the cycle.
#
# Copyright (C) 2012-2022 Free Software Foundation, Inc.
#
# Copying and distribution of this file, with or without modification,
# are permitted in any medium without royalty provided the copyright
# notice and this notice are preserved.
#
# Index by function name
#
#   [33] MAIN__ (ecrad_driver.F90) [151] __radiation_gas_MOD_scale_gas [24] rrtm_setcoef_140gp_
#  [163] __easy_netcdf_MOD_close_netcdf_file [203] __radiation_gas_MOD_set_units_gas [39] rrtm_taumol10_
#  [175] __easy_netcdf_MOD_create_netcdf_file [133] __radiation_ice_optics_fu_MOD_calc_ice_optics_fu_lw [25] rrtm_taumol11_
#  [168] __easy_netcdf_MOD_define_dimension [132] __radiation_ice_optics_fu_MOD_calc_ice_optics_fu_sw [26] rrtm_taumol12_
#  [144] __easy_netcdf_MOD_define_variable [3] __radiation_ifs_rrtm_MOD_gas_optics [40] rrtm_taumol13_
#  [176] __easy_netcdf_MOD_double_precision [10] __radiation_ifs_rrtm_MOD_planck_function_atmos [41] rrtm_taumol14_
#  [145] __easy_netcdf_MOD_end_define_mode [152] __radiation_ifs_rrtm_MOD_planck_function_surf [42] rrtm_taumol15_
#  [143] __easy_netcdf_MOD_exists [204] __radiation_ifs_rrtm_MOD_set_gas_units [43] rrtm_taumol16_
#  [136] __easy_netcdf_MOD_get_array_dimensions [205] __radiation_ifs_rrtm_MOD_setup_gas_optics [17] rrtm_taumol1_
#  [169] __easy_netcdf_MOD_get_global_attribute [2] __radiation_interface_MOD_radiation [44] rrtm_taumol2_
#  [146] __easy_netcdf_MOD_get_rank [206] __radiation_interface_MOD_set_gas_units [18] rrtm_taumol3_
#  [154] __easy_netcdf_MOD_get_real_array3 [207] __radiation_interface_MOD_setup_radiation [12] rrtm_taumol4_
#  [138] __easy_netcdf_MOD_get_real_matrix [131] __radiation_liquid_optics_socrates_MOD_calc_liq_optics_socrates [19] rrtm_taumol5_
#  [177] __easy_netcdf_MOD_get_real_scalar [13] __radiation_matrix_MOD_singlemat_x_vec [45] rrtm_taumol6_
#  [160] __easy_netcdf_MOD_get_real_vector [129] __radiation_overlap_MOD_calc_alpha_overlap_matrix [27] rrtm_taumol7_
#  [137] __easy_netcdf_MOD_get_variable_id [139] __radiation_overlap_MOD_calc_overlap_matrices [20] rrtm_taumol8_
#  [165] __easy_netcdf_MOD_open_netcdf_file [140] __radiation_regions_MOD_calc_region_properties [21] rrtm_taumol9_
#  [178] __easy_netcdf_MOD_permute_3d_arrays [208] __radiation_save_MOD_save_fluxes [87] srtm_cmbgb16_
#  [179] __easy_netcdf_MOD_put_global_attribute [153] __radiation_single_level_MOD_get_albedos [88] srtm_cmbgb17_
#  [180] __easy_netcdf_MOD_put_global_attributes [209] __radiation_single_level_MOD_init_seed_simple [89] srtm_cmbgb18_
#  [155] __easy_netcdf_MOD_put_real_matrix [210] __radiation_single_level_MOD_out_of_physical_bounds [90] srtm_cmbgb19_
#  [170] __easy_netcdf_MOD_put_real_vector [172] __radiation_spectral_definition_MOD_allocate_bands_only [91] srtm_cmbgb20_
#  [166] __easy_netcdf_MOD_transpose_matrices [173] __radiation_spectral_definition_MOD_calc_mapping_from_bands [92] srtm_cmbgb21_
#  [181] __ecrad_driver_config_MOD_read_config_from_namelist [135] __radiation_spectral_definition_MOD_calc_planck_function_wavenumber [93] srtm_cmbgb22_
#   [36] __ecrad_driver_read_input_MOD_read_input [174] __radiation_spectral_definition_MOD_deallocate [94] srtm_cmbgb23_
#   [15] __radiation_adding_ica_lw_MOD_calc_fluxes_no_scattering_lw [211] __radiation_thermodynamics_MOD_calc_saturation_wrt_liquid [95] srtm_cmbgb24_
#  [182] __radiation_aerosol_MOD_out_of_physical_bounds [212] __radiation_thermodynamics_MOD_out_of_physical_bounds [96] srtm_cmbgb25_
#    [7] __radiation_aerosol_optics_MOD_add_aerosol_optics [5] __radiation_tripleclouds_lw_MOD_solver_tripleclouds_lw [97] srtm_cmbgb26_
#  [134] __radiation_aerosol_optics_MOD_delta_eddington_extensive_vec [4] __radiation_tripleclouds_sw_MOD_solver_tripleclouds_sw [98] srtm_cmbgb27_
#  [183] __radiation_aerosol_optics_MOD_setup_aerosol_optics [11] __radiation_two_stream_MOD_calc_no_scattering_transmittance_lw [99] srtm_cmbgb28_
#  [130] __radiation_aerosol_optics_data_MOD_calc_rh_index [14] __radiation_two_stream_MOD_calc_ref_trans_lw [100] srtm_cmbgb29_
#  [156] __radiation_aerosol_optics_data_MOD_get_line (radiation_aerosol_optics_data.F90) [8] __radiation_two_stream_MOD_calc_ref_trans_sw [9] srtm_gas_optical_depth_
#  [184] __radiation_aerosol_optics_data_MOD_initialize_types [37] _init [101] srtm_init_
#  [185] __radiation_aerosol_optics_data_MOD_print_description [54] rrtm_cmbgb10_ [102] srtm_kgb16_
#  [164] __radiation_aerosol_optics_data_MOD_set_hydrophilic_type [55] rrtm_cmbgb11_ [103] srtm_kgb17_
#  [162] __radiation_aerosol_optics_data_MOD_set_hydrophobic_type [56] rrtm_cmbgb12_ [104] srtm_kgb18_
#  [186] __radiation_aerosol_optics_data_MOD_set_types [57] rrtm_cmbgb13_ [105] srtm_kgb19_
#  [187] __radiation_aerosol_optics_data_MOD_setup_aerosol_optics [58] rrtm_cmbgb14_ [106] srtm_kgb20_
#  [171] __radiation_check_MOD_out_of_bounds_1d [59] rrtm_cmbgb15_ [107] srtm_kgb21_
#  [142] __radiation_check_MOD_out_of_bounds_2d [60] rrtm_cmbgb16_ [108] srtm_kgb22_
#  [158] __radiation_check_MOD_out_of_bounds_3d [61] rrtm_cmbgb1_ [109] srtm_kgb23_
#  [188] __radiation_cloud_MOD_create_fractional_std [62] rrtm_cmbgb2_ [110] srtm_kgb24_
#  [157] __radiation_cloud_MOD_crop_cloud_fraction [63] rrtm_cmbgb3_ [111] srtm_kgb25_
#  [189] __radiation_cloud_MOD_out_of_physical_bounds [64] rrtm_cmbgb4_ [112] srtm_kgb26_
#   [23] __radiation_cloud_optics_MOD_cloud_optics [65] rrtm_cmbgb5_ [113] srtm_kgb27_
#  [128] __radiation_cloud_optics_MOD_delta_eddington_scat_od [66] rrtm_cmbgb6_ [114] srtm_kgb28_
#  [190] __radiation_cloud_optics_MOD_setup_cloud_optics [67] rrtm_cmbgb7_ [115] srtm_kgb29_
#  [191] __radiation_cloud_optics_data_MOD_setup_cloud_optics [68] rrtm_cmbgb8_ [28] srtm_setcoef_
#  [192] __radiation_config_MOD_consolidate_config [69] rrtm_cmbgb9_ [46] srtm_taumol16_
#  [193] __radiation_config_MOD_consolidate_lw_emiss_intervals [6] rrtm_gas_optical_depth_ [29] srtm_taumol17_
#  [194] __radiation_config_MOD_consolidate_sw_albedo_intervals [70] rrtm_init_140gp_ [30] srtm_taumol18_
#  [159] __radiation_config_MOD_get_enum_code [71] rrtm_kgb10_ [47] srtm_taumol19_
#  [195] __radiation_config_MOD_print_config [72] rrtm_kgb11_ [48] srtm_taumol20_
#  [161] __radiation_config_MOD_print_enum [73] rrtm_kgb12_ [22] srtm_taumol21_
#  [141] __radiation_config_MOD_print_logical [74] rrtm_kgb13_ [49] srtm_taumol22_
#  [167] __radiation_config_MOD_print_real [75] rrtm_kgb14_ [31] srtm_taumol23_
#  [196] __radiation_config_MOD_read_config_from_namelist [76] rrtm_kgb15_ [50] srtm_taumol24_
#  [197] __radiation_flux_MOD_allocate_flux_type [77] rrtm_kgb16_ [51] srtm_taumol25_
#  [147] __radiation_flux_MOD_calc_surface_spectral [78] rrtm_kgb1_ [52] srtm_taumol26_
#  [148] __radiation_flux_MOD_calc_toa_spectral [79] rrtm_kgb2_ [16] srtm_taumol27_
#  [198] __radiation_flux_MOD_out_of_physical_bounds [80] rrtm_kgb3_ [53] srtm_taumol28_
#  [199] __radiation_gas_MOD_allocate_gas [81] rrtm_kgb4_   [32] srtm_taumol29_
#  [149] __radiation_gas_MOD_assert_units_gas [82] rrtm_kgb5_ [116] surrtab_
#  [200] __radiation_gas_MOD_deallocate_gas [83] rrtm_kgb6_ [117] surrtftr_
#  [150] __radiation_gas_MOD_get_gas [84] rrtm_kgb7_       [118] surrtpk_
#  [201] __radiation_gas_MOD_out_of_physical_bounds [85] rrtm_kgb8_ [119] surrtrf_
#   [35] __radiation_gas_MOD_put_gas [86] rrtm_kgb9_       [120] susrtm_
#  [202] __radiation_gas_MOD_put_well_mixed_gas [38] rrtm_prepare_gases_

# %% [markdown]
# ## Environment

# %%
# %%bash
# source ${HOME}/conda/bin/activate tf2
# conda export --file requirements.yml
# Out:
# WARNING: overwriting environment variables set in the machine
# overwriting variable ['XLA_FLAGS', 'LD_LIBRARY_PATH']
