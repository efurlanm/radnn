# %%
! singularity --version
# Out:
# singularity-ce version 4.3.1-jammy

# %%
# %%bash
# singularity exec --nv \
#     --bind ~/torchfort_local:/torchfort \
#     ~/containers/torchfort.sif \
#     bash -c "cd /torchfort/build && make train_distributed"
# Out:
# CMake Error: Target DependInfo.cmake file not found
# [  5%] Built target torchfort_fort
# CMake Error: Target DependInfo.cmake file not found
# make[3]: *** No rule to make target '/usr/lib/x86_64-linux-gnu/libcuda.so', needed by 'lib/libtorchfort.so'.  Stop.
# make[2]: *** [CMakeFiles/Makefile2:144: CMakeFiles/torchfort.dir/all] Error 2
# make[1]: *** [CMakeFiles/Makefile2:310: examples/fortran/simulation/CMakeFiles/train_distributed.dir/rule] Error 2
# make: *** [Makefile:247: train_distributed] Error 2
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'singularity exec --nv \\\n    --bind ~/torchfort_local:/torchfort \\\n    ~/containers/torchfort.sif \\\n    bash -c "cd /torchfort/build && make train_distributed"\n')
#
# ...
